# %% [markdown]
# <a href="https://colab.research.google.com/github/rickyrahman/30-Days-Of-Python/blob/master/introtophyton.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World")
print("Ricky Rahman")
print(1+1)
print(2*6)
print(3*3)
print(3/3)
"print(3:3) model ini akan menampilkan error"
print(3**5) # artinya tiga pangkat 5
print(100//10) # artinya akar dari 100
print(3%2)

"checking data type"
print(type(200))
print(type(3.5))
print(type(5+8j))
print(type([1,2,3,4,5,6,7,8,9]))
print(type({"h","e","l","l","o"}))
print(type({2.4,3.8,4.7,5.8,6.9,7.4}))
print(type({'name': 'ricky'}))
# Out:
# Hello World
# Ricky Rahman
# 2
# 12
# 9
# 1.0
# 243
# 10
# 1
# <class 'int'>
# <class 'float'>
# <class 'complex'>
# <class 'list'>
# <class 'set'>
# <class 'set'>
# <class 'dict'>
